# %%
import pandas as pd
import os
os.getcwd()
# Out:
# '/Users/deepakm/mywork/Python_S1/cricket_data'

# %%
dlv=pd.read_csv("deliveries.csv")
dlv.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
dlv.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
dlm=pd.merge(dlv[['match_id', 'inning', 'batting_team']],mtch[mtchcols],how='left',left_on='match_id',right_on='id')
dlm.head()
# Out:
#    match_id  inning         batting_team  id  season               winner  \
# 0         1       1  Sunrisers Hyderabad   1    2017  Sunrisers Hyderabad
# 1         1       1  Sunrisers Hyderabad   1    2017  Sunrisers Hyderabad
# 2         1       1  Sunrisers Hyderabad   1    2017  Sunrisers Hyderabad
# 3         1       1  Sunrisers Hyderabad   1    2017  Sunrisers Hyderabad
# 4         1       1  Sunrisers Hyderabad   1    2017  Sunrisers Hyderabad
#
#   toss_decision
# 0         field
# 1         field
# 2         field
# 3         field
# 4         field

# %%
dlm=pd.merge(dlm,nmt,left_on='winner',right_on='FullName',how='left')
dlm.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...
#
#    player_dismissed  dismissal_kind  fielder  id  season             winner_x  \
# ...

# %%
# dlm.rename(columns={'winner_x':'winner'},inplace=True)
# dlm.drop(columns='winner_y',inplace=True)
dlm.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  total_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...           0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...           0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...           4
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...           0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...           2
#
# ...

# %%
mtch[mtchcols].head()
# Out:
#    id  season                       winner toss_decision
# 0   1    2017          Sunrisers Hyderabad         field
# 1   2    2017       Rising Pune Supergiant         field
# 2   3    2017        Kolkata Knight Riders         field
# 3   4    2017              Kings XI Punjab         field
# 4   5    2017  Royal Challengers Bangalore           bat

# %%
mtchcols=['id','season','winner','toss_decision']

# %%
mtch=pd.read_csv("matches.csv")
mtch.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
mtch.nunique()
# Out:
# id                 756
# season              12
# city                32
# date               546
# team1               15
# team2               15
# toss_winner         15
# toss_decision        2
# result               3
# dl_applied           2
# winner              15
# win_by_runs         89
# win_by_wickets      11
# player_of_match    226
# venue               41
# umpire1             61
# umpire2             65
# umpire3             25
# dtype: int64

# %%
nmt=pd.read_csv('NameTranslation.csv')
nmt['winner']=nmt.FullName
nmt.head()
# Out:
#                       FullName ShortName                       winner
# 0          Sunrisers Hyderabad        SH          Sunrisers Hyderabad
# 1               Mumbai Indians        MI               Mumbai Indians
# 2                Gujarat Lions        GL                Gujarat Lions
# 3       Rising Pune Supergiant       RPS       Rising Pune Supergiant
# 4  Royal Challengers Bangalore       RCB  Royal Challengers Bangalore

# %%
mtch=pd.merge(mtch,nmt,how='left',indicator=True)
print()
mtch.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied  ... win_by_runs  win_by_wickets  player_of_match  \
# ...

# %%
mtch._merge.value_counts()
# Out:
# both          752
# left_only       4
# right_only      0
# Name: _merge, dtype: int64

# %%
mtch.isna().sum()

# %%
mtch.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   season           756 non-null    int64
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           752 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          754 non-null    object
#  16  umpire2          754 non-null    object
# ...

# %%
dlv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179078 entries, 0 to 179077
# Data columns (total 22 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          179078 non-null  int64
#  1   inning            179078 non-null  int64
#  2   batting_team      179078 non-null  object
#  3   bowling_team      179078 non-null  object
#  4   over              179078 non-null  int64
#  5   ball              179078 non-null  int64
#  6   batsman           179078 non-null  object
#  7   non_striker       179078 non-null  object
#  8   bowler            179078 non-null  object
#  9   is_super_over     179078 non-null  int64
#  10  wide_runs         179078 non-null  int64
#  11  bye_runs          179078 non-null  int64
#  12  legbye_runs       179078 non-null  int64
#  13  noball_runs       179078 non-null  int64
#  14  penalty_runs      179078 non-null  int64
#  15  batsman_runs      179078 non-null  int64
# ...

# %%
dlv['id']=dlv.match_id.astype(str)

# %%
dlm=pd.merge(dlv,mtch[mtchcols],how='left')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-27d2e83ba213> in <module>
# ----> 1 dlm=pd.merge(dlv,mtch[mtchcols],how='left')
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      84         copy=copy,
#      85         indicator=indicator,
# ---> 86         validate=validate,
#      87     )
#      88     return op.get_result()
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     629         # validate the merge keys dtypes. We may need to coerce
#     630         # to avoid incompat dtypes
# --> 631         self._maybe_coerce_merge_keys()
#     632
# ...

# %%
tmp=mtch[mtchcols]
tmp
# Out:
#         id  season                       winner toss_decision
# 0        1    2017          Sunrisers Hyderabad         field
# 1        2    2017       Rising Pune Supergiant         field
# 2        3    2017        Kolkata Knight Riders         field
# 3        4    2017              Kings XI Punjab         field
# 4        5    2017  Royal Challengers Bangalore           bat
# ..     ...     ...                          ...           ...
# 751  11347    2019               Mumbai Indians         field
# 752  11412    2019               Mumbai Indians           bat
# 753  11413    2019               Delhi Capitals         field
# 754  11414    2019          Chennai Super Kings         field
# 755  11415    2019               Mumbai Indians           bat
#
# [756 rows x 4 columns]

# %%
tmp['id']=tmp.id.astype(str).str.zfill(5)
tmp
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#         id  season                       winner toss_decision
# 0    00001    2017          Sunrisers Hyderabad         field
# 1    00002    2017       Rising Pune Supergiant         field
# 2    00003    2017        Kolkata Knight Riders         field
# 3    00004    2017              Kings XI Punjab         field
# 4    00005    2017  Royal Challengers Bangalore           bat
# ..     ...     ...                          ...           ...
# 751  11347    2019               Mumbai Indians         field
# 752  11412    2019               Mumbai Indians           bat
# ...

# %%
tmp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             756 non-null    int64
#  1   season         756 non-null    int64
#  2   winner         752 non-null    object
#  3   toss_decision  756 non-null    object
# dtypes: int64(2), object(2)
# memory usage: 23.8+ KB

# %%
pd.concat

# %%
tmp1=tmp.loc[tmp.season==2017].reset_index()
tmp1['chkcol']='testing'
tmp2=tmp.loc[tmp.season==2019].reset_index()
tmp2['winner_x']='win'

# %%
tmp1
# Out:
#     index     id  season                       winner toss_decision   chkcol
# 0       0  00001    2017          Sunrisers Hyderabad         field  testing
# 1       1  00002    2017       Rising Pune Supergiant         field  testing
# 2       2  00003    2017        Kolkata Knight Riders         field  testing
# 3       3  00004    2017              Kings XI Punjab         field  testing
# 4       4  00005    2017  Royal Challengers Bangalore           bat  testing
# 5       5  00006    2017          Sunrisers Hyderabad         field  testing
# 6       6  00007    2017               Mumbai Indians         field  testing
# 7       7  00008    2017              Kings XI Punjab           bat  testing
# 8       8  00009    2017             Delhi Daredevils         field  testing
# 9       9  00010    2017               Mumbai Indians         field  testing
# 10     10  00011    2017        Kolkata Knight Riders         field  testing
# ...

# %%
tmp2
# Out:
#     index     id  season                       winner toss_decision winner_x
# 0     696  11137    2019          Chennai Super Kings         field      win
# 1     697  11138    2019        Kolkata Knight Riders         field      win
# 2     698  11139    2019               Delhi Capitals         field      win
# 3     699  11140    2019              Kings XI Punjab         field      win
# 4     700  11141    2019          Chennai Super Kings           bat      win
# 5     701  11142    2019        Kolkata Knight Riders         field      win
# 6     702  11143    2019               Mumbai Indians         field      win
# 7     703  11144    2019          Sunrisers Hyderabad           bat      win
# 8     704  11145    2019              Kings XI Punjab         field      win
# 9     705  11146    2019               Delhi Capitals         field      win
# 10    706  11147    2019          Sunrisers Hyderabad         field      win
# ...

# %%
pd.concat([tmp1,tmp2],axis=0)
# Out:
#         id  season                       winner toss_decision   chkcol  \
# 0    00001    2017          Sunrisers Hyderabad         field  testing
# 1    00002    2017       Rising Pune Supergiant         field  testing
# 2    00003    2017        Kolkata Knight Riders         field  testing
# 3    00004    2017              Kings XI Punjab         field  testing
# 4    00005    2017  Royal Challengers Bangalore           bat  testing
# ..     ...     ...                          ...           ...      ...
# 751  11347    2019               Mumbai Indians         field      NaN
# 752  11412    2019               Mumbai Indians           bat      NaN
# 753  11413    2019               Delhi Capitals         field      NaN
# 754  11414    2019          Chennai Super Kings         field      NaN
# 755  11415    2019               Mumbai Indians           bat      NaN
#
#     winner_x
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# ..       ...
# ...

# %%
pd.concat([tmp1,tmp2],axis=1)
# Out:
#     index     id  season                       winner toss_decision   chkcol  \
# 0     0.0  00001  2017.0          Sunrisers Hyderabad         field  testing
# 1     1.0  00002  2017.0       Rising Pune Supergiant         field  testing
# 2     2.0  00003  2017.0        Kolkata Knight Riders         field  testing
# 3     3.0  00004  2017.0              Kings XI Punjab         field  testing
# 4     4.0  00005  2017.0  Royal Challengers Bangalore           bat  testing
# 5     5.0  00006  2017.0          Sunrisers Hyderabad         field  testing
# 6     6.0  00007  2017.0               Mumbai Indians         field  testing
# 7     7.0  00008  2017.0              Kings XI Punjab           bat  testing
# 8     8.0  00009  2017.0             Delhi Daredevils         field  testing
# 9     9.0  00010  2017.0               Mumbai Indians         field  testing
# 10   10.0  00011  2017.0        Kolkata Knight Riders         field  testing
# ...

# %%
tmp1=tmp.loc[tmp.season==2017].reset_index()
tmp1.head()
# Out:
#    index     id  season                       winner toss_decision
# 0      0  00001    2017          Sunrisers Hyderabad         field
# 1      1  00002    2017       Rising Pune Supergiant         field
# 2      2  00003    2017        Kolkata Knight Riders         field
# 3      3  00004    2017              Kings XI Punjab         field
# 4      4  00005    2017  Royal Challengers Bangalore           bat

# %%
tmp1.set_index('winner',inplace=True)
tmp1.head()
# Out:
#                              index     id  season toss_decision
# winner
# Sunrisers Hyderabad              0  00001    2017         field
# Rising Pune Supergiant           1  00002    2017         field
# Kolkata Knight Riders            2  00003    2017         field
# Kings XI Punjab                  3  00004    2017         field
# Royal Challengers Bangalore      4  00005    2017           bat

# %%
nmt.set_index('winner',inplace=True)
nmt.head()
# Out:
#                                                 FullName ShortName
# winner
# Sunrisers Hyderabad                  Sunrisers Hyderabad        SH
# Mumbai Indians                            Mumbai Indians        MI
# Gujarat Lions                              Gujarat Lions        GL
# Rising Pune Supergiant            Rising Pune Supergiant       RPS
# Royal Challengers Bangalore  Royal Challengers Bangalore       RCB

# %%
dtlst=[tmp1,tmp2,nmt]

pd.concat(dtlst,axis=0)
# Out:
#                              index     id  season toss_decision winner  \
# Sunrisers Hyderabad            0.0  00001  2017.0         field    NaN
# Rising Pune Supergiant         1.0  00002  2017.0         field    NaN
# Kolkata Knight Riders          2.0  00003  2017.0         field    NaN
# Kings XI Punjab                3.0  00004  2017.0         field    NaN
# Royal Challengers Bangalore    4.0  00005  2017.0           bat    NaN
# ...                            ...    ...     ...           ...    ...
# Deccan Chargers                NaN    NaN     NaN           NaN    NaN
# Kochi Tuskers Kerala           NaN    NaN     NaN           NaN    NaN
# Pune Warriors                  NaN    NaN     NaN           NaN    NaN
# Rising Pune Supergiants        NaN    NaN     NaN           NaN    NaN
# Delhi Capitals                 NaN    NaN     NaN           NaN    NaN
#
#                             winner_x                 FullName ShortName
# ...

# %%
nmt.shape
# Out:
# (15, 2)

# %%
tmp1.shape
# Out:
# (59, 4)
